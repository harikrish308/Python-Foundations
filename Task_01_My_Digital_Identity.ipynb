# %% [markdown]
# <a href="https://colab.research.google.com/github/harikrish308/Python-Foundations/blob/main/Task_01_My_Digital_Identity.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Task 1 - My Digital Identity
name = "Hari Krishnan"
reg_no = "JSOFT26241"
department = "BCA"
semester = 1
skills = "Python, Git, Problem Solving"
hobbies = "Reading , Cricket"
dream_company = "Google"
github = "https://github.com/harikrish308"
linkedin = "www.linkedin.com/in/hari-krishnan-071010416"
career_goal = "Software Engineer / Product Builder / Entreprenuer"

print("=" * 40)
print("        MY DIGITAL IDENTITY")
print("=" * 40)
print(f"Name         : {name}")
print(f"Reg Number   : {reg_no}")
print(f"Department   : {department}")
print(f"Semester     : {semester}")
print(f"Skills       : {skills}")
print(f"Hobbies      : {hobbies}")
print(f"Dream Company: {dream_company}")
print(f"GitHub       : {github}")
print(f"LinkedIn     : {linkedin}")
print(f"Career Goal  : {career_goal}")
print("=" * 40)
# Out:
# ...
#         MY DIGITAL IDENTITY
# ...
# Name         : Hari Krishnan
# Reg Number   : JSOFT26241
# Department   : BCA
# Semester     : 1
# Skills       : Python, Git, Problem Solving
# Hobbies      : Reading , Cricket
# Dream Company: Google
# GitHub       : https://github.com/harikrish308
# LinkedIn     : www.linkedin.com/in/hari-krishnan-071010416
# Career Goal  : Software Engineer / Product Builder / Entreprenuer
# ...
