# %% [markdown]
# <a href="https://colab.research.google.com/github/harikrish308/Python-Foundations/blob/main/Task_03_Resume_Generator.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Task 3 - Resume Generator
name = input("Full Name: ")
education = input("Education: ")
skills = input("Skills (comma separated): ")
projects = input("Projects (comma separated): ")
languages = input("Languages known: ")

print("\n" + "=" * 45)
print(f"{name.upper():^45}")
print("=" * 45)

print("\nEDUCATION")
print("-" * 45)
print(education)

print("\nSKILLS")
print("-" * 45)
for s in skills.split(","):
    print(f"  • {s.strip()}")

print("\nPROJECTS")
print("-" * 45)
for p in projects.split(","):
    print(f"  • {p.strip()}")

print("\nLANGUAGES")
print("-" * 45)
print(languages)
print("=" * 45)
# Out:
# Full Name: Hari Krishnan
# Education: BCA Full Stack Development
# Skills (comma separated): C++ , Python , Web Designing , Communication skills
# Projects (comma separated): Digital Identity Creator , Student Profile Managing Web
# Languages known: Malayalam , English , Hindi
#
# ...
#                 HARI KRISHNAN
# ...
#
# EDUCATION
# ---------------------------------------------
# BCA Full Stack Development
#
# SKILLS
# ---------------------------------------------
#   • C++
#   • Python
#   • Web Designing
#   • Communication skills
#
# PROJECTS
# ---------------------------------------------
#   • Digital Identity Creator
#   • Student Profile Managing Web
#
# LANGUAGES
# ---------------------------------------------
# Malayalam , English , Hindi
# ...
